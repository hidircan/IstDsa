# %%
import seaborn as sns

# %%
import matplotlib as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
df_1 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_230325.txt')

# %%
df_1.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  12:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7845085
# 1  REGULAR  7845089
# 2  REGULAR  7845100
# 3  REGULAR  7845144
# 4  REGULAR  7845220
# 5  REGULAR  7845335
# 6  REGULAR  7845375
# ...

# %%
df_1.dtypes
# Out:
# C/A                                                                     object
# UNIT                                                                    object
# SCP                                                                     object
# STATION                                                                 object
# LINENAME                                                                object
# DIVISION                                                                object
# DATE                                                                    object
# TIME                                                                    object
# DESC                                                                    object
# ENTRIES                                                                  int64
# EXITS                                                                    int64
# dtype: object

# %%
df_1.isnull().sum()
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
df_1.dropna(inplace=True)

# %%
df_1.rename(columns={"EXITS                                                               ": "EXITS"}, inplace=True)

# %%
df_1['TURNSTILE'] = df_1['C/A'] + ' ' + df_1['UNIT'] + ' ' + df_1['SCP'] + ' ' +df_1['STATION']

# %%
df_1.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/18/2023  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/19/2023  12:00:00
#
#       DESC  ENTRIES    EXITS                 TURNSTILE
# 0  REGULAR  7845085  2795877  A002 R051 02-00-00 59 ST
# 1  REGULAR  7845089  2795888  A002 R051 02-00-00 59 ST
# ...

# %%
df_1.drop(['LINENAME'],axis = 1,inplace = True)

# %%
df_1.drop(['DIVISION'],axis = 1,inplace = True)

# %%
df_1.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE      TIME     DESC  ENTRIES  \
# 0  A002  R051  02-00-00   59 ST  03/18/2023  00:00:00  REGULAR  7845085
# 1  A002  R051  02-00-00   59 ST  03/18/2023  04:00:00  REGULAR  7845089
# 2  A002  R051  02-00-00   59 ST  03/18/2023  08:00:00  REGULAR  7845100
# 3  A002  R051  02-00-00   59 ST  03/18/2023  12:00:00  REGULAR  7845144
# 4  A002  R051  02-00-00   59 ST  03/18/2023  16:00:00  REGULAR  7845220
#
#      EXITS                 TURNSTILE
# 0  2795877  A002 R051 02-00-00 59 ST
# 1  2795888  A002 R051 02-00-00 59 ST
# 2  2795911  A002 R051 02-00-00 59 ST
# 3  2795973  A002 R051 02-00-00 59 ST
# 4  2796037  A002 R051 02-00-00 59 ST

# %%
df_1.drop(['UNIT'],axis = 1,inplace = True)

# %%
df_1.drop(['SCP'],axis = 1,inplace = True)

# %%
df_1.head()
# Out:
#     C/A STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0  A002   59 ST  03/18/2023  00:00:00  REGULAR  7845085  2795877
# 1  A002   59 ST  03/18/2023  04:00:00  REGULAR  7845089  2795888
# 2  A002   59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3  A002   59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4  A002   59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
#
#                   TURNSTILE
# 0  A002 R051 02-00-00 59 ST
# 1  A002 R051 02-00-00 59 ST
# 2  A002 R051 02-00-00 59 ST
# 3  A002 R051 02-00-00 59 ST
# 4  A002 R051 02-00-00 59 ST

# %%
df2 = df_1.copy()

# %%
df2.head()
# Out:
#     C/A STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0  A002   59 ST  03/18/2023  00:00:00  REGULAR  7845085  2795877
# 1  A002   59 ST  03/18/2023  04:00:00  REGULAR  7845089  2795888
# 2  A002   59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3  A002   59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4  A002   59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
#
#                   TURNSTILE
# 0  A002 R051 02-00-00 59 ST
# 1  A002 R051 02-00-00 59 ST
# 2  A002 R051 02-00-00 59 ST
# 3  A002 R051 02-00-00 59 ST
# 4  A002 R051 02-00-00 59 ST

# %%
grouped = df2.groupby("TURNSTILE")

# %%
diff = lambda x: x["ENTRIES"].replace(0, np.NaN).dropna().diff()

# %%
df2["DIFF"] = grouped.apply(diff).reset_index(0, drop=True)

# %%
df2.head()
# Out:
#     C/A STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0  A002   59 ST  03/18/2023  00:00:00  REGULAR  7845085  2795877
# 1  A002   59 ST  03/18/2023  04:00:00  REGULAR  7845089  2795888
# 2  A002   59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3  A002   59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4  A002   59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
#
#                   TURNSTILE  DIFF
# 0  A002 R051 02-00-00 59 ST   NaN
# 1  A002 R051 02-00-00 59 ST   4.0
# 2  A002 R051 02-00-00 59 ST  11.0
# 3  A002 R051 02-00-00 59 ST  44.0
# 4  A002 R051 02-00-00 59 ST  76.0

# %%
df2.dtypes
# Out:
# C/A           object
# STATION       object
# DATE          object
# TIME          object
# DESC          object
# ENTRIES        int64
# EXITS          int64
# TURNSTILE     object
# DIFF         float64
# dtype: object

# %%
df2[df2['DIFF']<0]
# Out:
#          C/A          STATION        DATE      TIME     DESC     ENTRIES  \
# 1639    A011       57 ST-7 AV  03/18/2023  04:00:00  REGULAR   885365548
# 1640    A011       57 ST-7 AV  03/18/2023  08:00:00  REGULAR   885365542
# 1641    A011       57 ST-7 AV  03/18/2023  12:00:00  REGULAR   885365513
# 1642    A011       57 ST-7 AV  03/18/2023  16:00:00  REGULAR   885365425
# 1643    A011       57 ST-7 AV  03/18/2023  20:00:00  REGULAR   885365330
# ...      ...              ...         ...       ...      ...         ...
# 209324  R730  EASTCHSTER/DYRE  03/24/2023  05:00:00  REGULAR  1559711114
# 209325  R730  EASTCHSTER/DYRE  03/24/2023  09:00:00  REGULAR  1559710981
# 209326  R730  EASTCHSTER/DYRE  03/24/2023  13:00:00  REGULAR  1559710953
# 209327  R730  EASTCHSTER/DYRE  03/24/2023  17:00:00  REGULAR  1559710904
# 209328  R730  EASTCHSTER/DYRE  03/24/2023  21:00:00  REGULAR  1559710883
#
#              EXITS                           TURNSTILE   DIFF
# ...

# %%
df2.reset_index
# Out:
# <bound method DataFrame.reset_index of           C/A        STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0        A002          59 ST  03/18/2023  00:00:00  REGULAR  7845085  2795877
# 1        A002          59 ST  03/18/2023  04:00:00  REGULAR  7845089  2795888
# 2        A002          59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3        A002          59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4        A002          59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
# ...       ...            ...         ...       ...      ...      ...      ...
# 211136  TRAM2  RIT-ROOSEVELT  03/24/2023  05:00:00  REGULAR        0     1117
# 211137  TRAM2  RIT-ROOSEVELT  03/24/2023  09:00:00  REGULAR        0     1117
# 211138  TRAM2  RIT-ROOSEVELT  03/24/2023  13:00:00  REGULAR        0     1117
# 211139  TRAM2  RIT-ROOSEVELT  03/24/2023  17:00:00  REGULAR        0     1117
# ...

# %%
df2.head()
# Out:
#     C/A STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0  A002   59 ST  03/18/2023  00:00:00  REGULAR  7845085  2795877
# 1  A002   59 ST  03/18/2023  04:00:00  REGULAR  7845089  2795888
# 2  A002   59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3  A002   59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4  A002   59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
#
#                   TURNSTILE  DIFF
# 0  A002 R051 02-00-00 59 ST   NaN
# 1  A002 R051 02-00-00 59 ST   4.0
# 2  A002 R051 02-00-00 59 ST  11.0
# 3  A002 R051 02-00-00 59 ST  44.0
# 4  A002 R051 02-00-00 59 ST  76.0

# %%
df2.iloc[1630:1650]
# Out:
#        C/A     STATION        DATE      TIME     DESC    ENTRIES      EXITS  \
# 1630  A011  57 ST-7 AV  03/23/2023  16:00:00  REGULAR    5059799    3789774
# 1631  A011  57 ST-7 AV  03/23/2023  20:00:00  REGULAR    5060205    3790016
# 1632  A011  57 ST-7 AV  03/24/2023  00:00:00  REGULAR    5060448    3790099
# 1633  A011  57 ST-7 AV  03/24/2023  04:00:00  REGULAR    5060478    3790117
# 1634  A011  57 ST-7 AV  03/24/2023  08:00:00  REGULAR    5060538    3790342
# 1635  A011  57 ST-7 AV  03/24/2023  12:00:00  REGULAR    5060706    3790731
# 1636  A011  57 ST-7 AV  03/24/2023  16:00:00  REGULAR    5060956    3790965
# 1637  A011  57 ST-7 AV  03/24/2023  20:00:00  REGULAR    5061300    3791247
# 1638  A011  57 ST-7 AV  03/18/2023  00:00:00  REGULAR  885365568  488680581
# 1639  A011  57 ST-7 AV  03/18/2023  04:00:00  REGULAR  885365548  488680544
# 1640  A011  57 ST-7 AV  03/18/2023  08:00:00  REGULAR  885365542  488680429
# ...

# %%
df2.dropna(inplace=True)

# %%
df2[df2['DIFF']<0]
# Out:
#          C/A          STATION        DATE      TIME     DESC     ENTRIES  \
# 1639    A011       57 ST-7 AV  03/18/2023  04:00:00  REGULAR   885365548
# 1640    A011       57 ST-7 AV  03/18/2023  08:00:00  REGULAR   885365542
# 1641    A011       57 ST-7 AV  03/18/2023  12:00:00  REGULAR   885365513
# 1642    A011       57 ST-7 AV  03/18/2023  16:00:00  REGULAR   885365425
# 1643    A011       57 ST-7 AV  03/18/2023  20:00:00  REGULAR   885365330
# ...      ...              ...         ...       ...      ...         ...
# 209324  R730  EASTCHSTER/DYRE  03/24/2023  05:00:00  REGULAR  1559711114
# 209325  R730  EASTCHSTER/DYRE  03/24/2023  09:00:00  REGULAR  1559710981
# 209326  R730  EASTCHSTER/DYRE  03/24/2023  13:00:00  REGULAR  1559710953
# 209327  R730  EASTCHSTER/DYRE  03/24/2023  17:00:00  REGULAR  1559710904
# 209328  R730  EASTCHSTER/DYRE  03/24/2023  21:00:00  REGULAR  1559710883
#
#              EXITS                           TURNSTILE   DIFF
# ...

# %%
df2[df2['DIFF']<0]
# Out:
#          C/A          STATION        DATE      TIME     DESC     ENTRIES  \
# 1639    A011       57 ST-7 AV  03/18/2023  04:00:00  REGULAR   885365548
# 1640    A011       57 ST-7 AV  03/18/2023  08:00:00  REGULAR   885365542
# 1641    A011       57 ST-7 AV  03/18/2023  12:00:00  REGULAR   885365513
# 1642    A011       57 ST-7 AV  03/18/2023  16:00:00  REGULAR   885365425
# 1643    A011       57 ST-7 AV  03/18/2023  20:00:00  REGULAR   885365330
# ...      ...              ...         ...       ...      ...         ...
# 209324  R730  EASTCHSTER/DYRE  03/24/2023  05:00:00  REGULAR  1559711114
# 209325  R730  EASTCHSTER/DYRE  03/24/2023  09:00:00  REGULAR  1559710981
# 209326  R730  EASTCHSTER/DYRE  03/24/2023  13:00:00  REGULAR  1559710953
# 209327  R730  EASTCHSTER/DYRE  03/24/2023  17:00:00  REGULAR  1559710904
# 209328  R730  EASTCHSTER/DYRE  03/24/2023  21:00:00  REGULAR  1559710883
#
#              EXITS                           TURNSTILE   DIFF
# ...

# %%
df2['DIFF'] = df2['DIFF'].abs()

# %%
df2[df2['DIFF']<0]
# Out:
# Empty DataFrame
# Columns: [C/A, STATION, DATE, TIME, DESC, ENTRIES, EXITS, TURNSTILE, DIFF]
# Index: []

# %%
df2.iloc[1630:1650]
# Out:
#        C/A     STATION        DATE      TIME     DESC  ENTRIES   EXITS  \
# 1712  A011  57 ST-7 AV  03/23/2023  08:00:00  REGULAR   365159  669913
# 1713  A011  57 ST-7 AV  03/23/2023  12:00:00  REGULAR   365224  670431
# 1714  A011  57 ST-7 AV  03/23/2023  16:00:00  REGULAR   365330  670662
# 1715  A011  57 ST-7 AV  03/23/2023  20:00:00  REGULAR   365574  670898
# 1716  A011  57 ST-7 AV  03/24/2023  00:00:00  REGULAR   365701  671009
# 1717  A011  57 ST-7 AV  03/24/2023  04:00:00  REGULAR   365728  671028
# 1718  A011  57 ST-7 AV  03/24/2023  08:00:00  REGULAR   365748  671155
# 1719  A011  57 ST-7 AV  03/24/2023  12:00:00  REGULAR   365803  671474
# 1720  A011  57 ST-7 AV  03/24/2023  16:00:00  REGULAR   365906  671737
# 1721  A011  57 ST-7 AV  03/24/2023  20:00:00  REGULAR   366071  672048
# 1723  A011  57 ST-7 AV  03/18/2023  04:00:00  REGULAR   119843  289657
# 1724  A011  57 ST-7 AV  03/18/2023  08:00:00  REGULAR   119859  289709
# ...

# %%
df2.rename(columns={"EXITS                                                               ": "EXITS"}, inplace=True)

# %%
grouped2 = df2.groupby("TURNSTILE")

# %%
diff2 = lambda x: x["EXITS"].replace(0, np.NaN).dropna().diff()

# %%
df2["DIFF2"] = grouped2.apply(diff2).reset_index(0, drop=True)

# %%
df2.head()
# Out:
#     C/A STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 1  A002   59 ST  03/18/2023  04:00:00  REGULAR  7845089  2795888
# 2  A002   59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3  A002   59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4  A002   59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
# 5  A002   59 ST  03/18/2023  20:00:00  REGULAR  7845335  2796086
#
#                   TURNSTILE   DIFF  DIFF2
# 1  A002 R051 02-00-00 59 ST    4.0    NaN
# 2  A002 R051 02-00-00 59 ST   11.0   23.0
# 3  A002 R051 02-00-00 59 ST   44.0   62.0
# 4  A002 R051 02-00-00 59 ST   76.0   64.0
# 5  A002 R051 02-00-00 59 ST  115.0   49.0

# %%
df2.dropna(inplace=True)

# %%
df2.reset_index
# Out:
# <bound method DataFrame.reset_index of           C/A        STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 2        A002          59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 3        A002          59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 4        A002          59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
# 5        A002          59 ST  03/18/2023  20:00:00  REGULAR  7845335  2796086
# 6        A002          59 ST  03/19/2023  00:00:00  REGULAR  7845375  2796136
# ...       ...            ...         ...       ...      ...      ...      ...
# 211050  TRAM2  RIT-ROOSEVELT  03/24/2023  05:00:00  REGULAR  3281743   407761
# 211051  TRAM2  RIT-ROOSEVELT  03/24/2023  09:00:00  REGULAR  3281753   407763
# 211052  TRAM2  RIT-ROOSEVELT  03/24/2023  13:00:00  REGULAR  3281791   407764
# 211053  TRAM2  RIT-ROOSEVELT  03/24/2023  17:00:00  REGULAR  3281880   407766
# ...

# %%
df2['DIFF2'] = df2['DIFF2'].abs()

# %%
df2[df2['DIFF']<0]
# Out:
# Empty DataFrame
# Columns: [C/A, STATION, DATE, TIME, DESC, ENTRIES, EXITS, TURNSTILE, DIFF, DIFF2]
# Index: []

# %%
df2[df2['DIFF2']<0]
# Out:
# Empty DataFrame
# Columns: [C/A, STATION, DATE, TIME, DESC, ENTRIES, EXITS, TURNSTILE, DIFF, DIFF2]
# Index: []

# %%
df2['TOTAL']= df2['DIFF'] + df2['DIFF2']

# %%
df2.reset_index(0, inplace=True)

# %%
df2.head(15)
# Out:
#     index   C/A STATION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0       2  A002   59 ST  03/18/2023  08:00:00  REGULAR  7845100  2795911
# 1       3  A002   59 ST  03/18/2023  12:00:00  REGULAR  7845144  2795973
# 2       4  A002   59 ST  03/18/2023  16:00:00  REGULAR  7845220  2796037
# 3       5  A002   59 ST  03/18/2023  20:00:00  REGULAR  7845335  2796086
# 4       6  A002   59 ST  03/19/2023  00:00:00  REGULAR  7845375  2796136
# 5       7  A002   59 ST  03/19/2023  04:00:00  REGULAR  7845379  2796143
# 6       8  A002   59 ST  03/19/2023  08:00:00  REGULAR  7845388  2796159
# 7       9  A002   59 ST  03/19/2023  12:00:00  REGULAR  7845409  2796215
# 8      10  A002   59 ST  03/19/2023  16:00:00  REGULAR  7845461  2796268
# 9      11  A002   59 ST  03/19/2023  20:00:00  REGULAR  7845545  2796294
# 10     12  A002   59 ST  03/20/2023  00:00:00  REGULAR  7845587  2796320
# 11     13  A002   59 ST  03/20/2023  04:00:00  REGULAR  7845591  2796325
# ...

# %%
df2[df2['DIFF']>60000].head(20)
# Out:
#          index    C/A         STATION        DATE      TIME     DESC  \
# 32214    35891   H026  MYRTLE-WYCKOFF  03/24/2023  16:00:00  REGULAR
# 42861    48066   N023          135 ST  03/23/2023  05:00:00  REGULAR
# 49731    55575   N067  34 ST-PENN STA  03/18/2023  16:00:00  REGULAR
# 57098    63687   N098       FULTON ST  03/19/2023  15:00:00  REGULAR
# 73088    81920  N309A    QUEENS PLAZA  03/23/2023  09:00:00  REGULAR
# 103068  115503   N701     86 ST-2 AVE  03/23/2023  17:00:00  REGULAR
# 103673  116138   N702     96 ST-2 AVE  03/24/2023  13:00:00  REGULAR
# 112545  125646  PTH18    NEWARK BM BW  03/22/2023  21:20:01  REGULAR
# 112800  125915  PTH18    NEWARK BM BW  03/20/2023  18:46:10  REGULAR
# 112801  125916  PTH18    NEWARK BM BW  03/20/2023  19:18:10  REGULAR
# 112802  125917  PTH18    NEWARK BM BW  03/20/2023  22:58:10  REGULAR
# 112803  125918  PTH18    NEWARK BM BW  03/20/2023  23:30:10  REGULAR
# 156681  173848   R289      FORDHAM RD  03/21/2023  12:00:00  REGULAR
#
# ...

# %%
df2 = df2[df2['DIFF']<60000]

# %%
dft= df2.groupby(["DATE",'STATION']).TOTAL.sum()

# %%
dft.describe().astype('int')
# Out:
# count       2646
# mean       14602
# std        35199
# min            0
# 25%         3850
# 50%         7419
# 75%        15435
# max      1418996
# Name: TOTAL, dtype: int32

# %%
df2 = df2[df2['DIFF2']<60000]

# %%
df2.sort_values(by=['TOTAL'],ascending=False)
# Out:
#          index    C/A         STATION        DATE      TIME     DESC  \
# 115136  128377  PTH22    PATH NEW WTC  03/24/2023  15:08:46  REGULAR
# 106288  118975  PTH03  JOURNAL SQUARE  03/22/2023  20:15:33  REGULAR
# 106287  118974  PTH03  JOURNAL SQUARE  03/22/2023  17:19:56  REGULAR
# 102490  114855   N700     72 ST-2 AVE  03/20/2023  13:00:00  REGULAR
# 6179      6787   A042       PRINCE ST  03/20/2023  16:00:00  REGULAR
# ...        ...    ...             ...         ...       ...      ...
# 148623  165260  R242A           51 ST  03/19/2023  20:00:00  REGULAR
# 105959  118630  PTH03  JOURNAL SQUARE  03/18/2023  13:46:47  REGULAR
# 148624  165261  R242A           51 ST  03/20/2023  00:00:00  REGULAR
# 141985  157993   R221  14 ST-UNION SQ  03/24/2023  05:00:00  REGULAR
# 170720  189932   R514    ASTORIA BLVD  03/22/2023  04:00:00  REGULAR
#
#          ENTRIES      EXITS                           TURNSTILE     DIFF  \
# ...

# %%
#del df2['AA']
del df2['index']

# %%
dft.describe().astype('int')
# Out:
# count       2646
# mean       14602
# std        35199
# min            0
# 25%         3850
# 50%         7419
# 75%        15435
# max      1418996
# Name: TOTAL, dtype: int32

# %%
ddft = dft.sort_values(ascending=False)

# %%
dft= df2.groupby(["DATE",'STATION']).TOTAL.sum()

# %%
dft.describe().astype('int')
# Out:
# count      2646
# mean      13835
# std       19532
# min           0
# 25%        3850
# 50%        7419
# 75%       15427
# max      213215
# Name: TOTAL, dtype: int32

# %%
df3=df2.groupby(['STATION']).TOTAL.sum()

# %%
df3 = df3.to_frame()

# %%
df3['STATION']=df3.index

# %%
#dfs.describe().astype('int')

# %%
df3 = df3.reset_index(drop=True)

# %%
df3 = df3.sort_values(by='TOTAL',ascending=False)

# %%
df3 = df3.reset_index(drop=True)

# %%
df3
# Out:
#         TOTAL          STATION
# 0    930048.0   34 ST-PENN STA
# 1    870361.0  GRD CNTRL-42 ST
# 2    700014.0  34 ST-HERALD SQ
# 3    646646.0   TIMES SQ-42 ST
# 4    643900.0   14 ST-UNION SQ
# ..        ...              ...
# 373    4073.0      BEACH 98 ST
# 374    3827.0  AQUEDUCT RACETR
# 375    1991.0     BEACH 105 ST
# 376    1241.0    BROAD CHANNEL
# 377    1024.0    TOMPKINSVILLE
#
# [378 rows x 2 columns]

# %%
df4=df3.head(10)

# %%
sns.catplot(x='STATION',y='TOTAL',data=df4,aspect=8,height=4,kind='point');

# %%
dft
# Out:
# DATE        STATION
# 03/18/2023  1 AV               13485.0
#             103 ST             13998.0
#             103 ST-CORONA      16078.0
#             104 ST               664.0
#             110 ST              4724.0
#                                 ...
# 03/24/2023  WOODLAWN            6135.0
#             WORLD TRADE CTR    14073.0
#             WTC-CORTLANDT      12491.0
#             YORK ST             9260.0
#             ZEREGA AV           3105.0
# Name: TOTAL, Length: 2646, dtype: float64

# %%
dft = dft.to_frame()

# %%
dft
# Out:
#                               TOTAL
# DATE       STATION
# 03/18/2023 1 AV             13485.0
#            103 ST           13998.0
#            103 ST-CORONA    16078.0
#            104 ST             664.0
#            110 ST            4724.0
# ...                             ...
# 03/24/2023 WOODLAWN          6135.0
#            WORLD TRADE CTR  14073.0
#            WTC-CORTLANDT    12491.0
#            YORK ST           9260.0
#            ZEREGA AV         3105.0
#
# [2646 rows x 1 columns]

# %%
dft['DATE']=dft.index

# %%
dft['DATE&STATION']=dft['DATE']

# %%
dft.drop('DATE',axis=1,inplace=True)

# %%
dft = dft.reset_index(drop=True)

# %%
dft
# Out:
#         TOTAL                   DATE&STATION
# 0     13485.0             (03/18/2023, 1 AV)
# 1     13998.0           (03/18/2023, 103 ST)
# 2     16078.0    (03/18/2023, 103 ST-CORONA)
# 3       664.0           (03/18/2023, 104 ST)
# 4      4724.0           (03/18/2023, 110 ST)
# ...       ...                            ...
# 2641   6135.0         (03/24/2023, WOODLAWN)
# 2642  14073.0  (03/24/2023, WORLD TRADE CTR)
# 2643  12491.0    (03/24/2023, WTC-CORTLANDT)
# 2644   9260.0          (03/24/2023, YORK ST)
# 2645   3105.0        (03/24/2023, ZEREGA AV)
#
# [2646 rows x 2 columns]

# %%
dft=dft.sort_values(by='TOTAL',ascending=False)

# %%
dft
# Out:
#          TOTAL                   DATE&STATION
# 1770  213215.0   (03/22/2023, JOURNAL SQUARE)
# 1195  160148.0   (03/21/2023, 34 ST-PENN STA)
# 1745  159092.0  (03/22/2023, GRD CNTRL-42 ST)
# 1951  158292.0   (03/23/2023, 34 ST-PENN STA)
# 1573  157701.0   (03/22/2023, 34 ST-PENN STA)
# ...        ...                            ...
# 134        3.0         (03/18/2023, AVENUE X)
# 512        2.0         (03/19/2023, AVENUE X)
# 109        0.0  (03/18/2023, 85 ST-FOREST PK)
# 576        0.0    (03/19/2023, CYPRESS HILLS)
# 198        0.0    (03/18/2023, CYPRESS HILLS)
#
# [2646 rows x 2 columns]

# %%
dft=dft[dft['TOTAL']!=0]

# %%
dft=dft.head(30)

# %%
sns.distplot(dft.TOTAL);
# Out:
# C:\Users\aulas\AppData\Local\Temp\ipykernel_10612\3802368946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dft.TOTAL);

# %%
dft=dft.head(6)

# %%
sns.catplot(x='DATE&STATION',y='TOTAL',data=dft,aspect=8,height=2,kind='point');
